# %% [markdown]
# CHAMADO COM OS HEADERS E OS PARAMETROS NECESSÁRIOS, colocando o resultado JSON em um dataFrame pandas para analise e tratamento de dados

# %%
import pandas as pd
import requests
import json

data = {
    "grant_type": "",
    "client_id": "",
    "client_secret": "",
    "username": "zimmer.gomes@apexbrasil.com.br",
    "password": "KBBr12gcuPUSrKd8",
    "scope": ""
}
chamado = requests.post("https://api-test.spendnetwork.cloud/api/v2/login/access-token", data=data)
chamado.raise_for_status()
print(chamado.status_code)

tok = chamado.json()["access_token"]
headers = {
    "Content-Type": "application/x-www-form-urlencoded",
    "Accept": "application/json",
    "Authorization": f"Bearer {tok}"
}

testtoken = requests.post("https://api-test.spendnetwork.cloud/api/v2/login/test-token", headers=headers)
testtoken.raise_for_status()
print(testtoken.content)
headers = {
    'accept': 'application/json',
    'Authorization': 'Bearer ' + tok
}
params = {
    'cpv__is': '48110000',
    # 'buyer_name__is' : 'CENTRAL DE ABASTECIMIENTO DEL SISTEMA NACIONAL DE SERVICIO DE SALUD, Compras del Giro 621',
    'buyer_address_country_name__is': 'Chile',
    #'buyer_address_country_code__is': 'GER',
    'release_date__gte': '2023-06-20T00:00:00',
    # 'tender_deadline__gte' : '2023-05-31T00:00:00',
    'compiled_only': 'false',
    'original_only': 'false',
    'date_direction': 'desc',
    'offset': '0',
    'limit': '100'
}
chamado = requests.post("https://api-test.spendnetwork.cloud/api/v2/login/access-token", data=data)
chamado.raise_for_status()
print(chamado.status_code)
print(chamado.content)

tok = chamado.json()["access_token"]

# NOTICES

# -- Read Records -- 
#chamado = requests.get('https://api-test.spendnetwork.cloud/api/v2/notices/records', headers=headers,
#                       params=params)
#print(chamado.status_code)
#resposta_JSON = json.loads(chamado.content)

# -- Records by Id --
#chamado = requests.get('https://api-test.spendnetwork.cloud/api/v2/notices/{ocid__is}', headers=headers,
#                       params=params)
#print(chamado.status_code)
#resposta_JSON = json.loads(chamado.content)


# TRANSACTIONS

# -- Read Records -- 
#chamado = requests.get('https://api-test.spendnetwork.cloud/api/v2/transactions/records', headers=headers,
#                       params=params)
#print(chamado.status_code)
#resposta_JSON = json.loads(chamado.content)

# -- Aggregate Amount -- 
#chamado = requests.get('https://api-test.spendnetwork.cloud/api/v2/transactions/aggregate_amount', headers=headers,
#                       params=params)
#print(chamado.status_code)
#resposta_JSON = json.loads(chamado.content)

# -- Timeline --
#chamado = requests.get('https://api-test.spendnetwork.cloud/api/v2/transactions/timeline', headers=headers,
#                      params=params)
#print(chamado.status_code)
#resposta_JSON = json.loads(chamado.content)

# -- Spend Values -- 
#chamado = requests.get('https://api-test.spendnetwork.cloud/api/v2/transactions/values', headers=headers,
#                       params=params)
#print(chamado.status_code)
#resposta_JSON = json.loads(chamado.content)
#print(resposta_JSON)

#------------------------------------------------------------------------------------------------------------------------
# DESCOMENTAR A LINHA ABAIXO APENAS PARA AS OPÇÕES ACIMA:
#df = pd.DataFrame(resposta_JSON)
#------------------------------------------------------------------------------------------------------------------------

             # AQUI PARA BAIXO E APENAS UMA RESPOSTA JSON COM UM NUMERO BRUTO

# -- Buyer Total Number --
#chamado = requests.get('https://api-test.spendnetwork.cloud/api/v2/transactions/buyer_total', headers=headers,
#                       params=params)
#print(chamado.status_code)
#resposta_JSON = json.loads(chamado.content)
#print(resposta_JSON)

# -- Spend Supplier Total Number --
#chamado = requests.get('https://api-test.spendnetwork.cloud/api/v2/transactions/supplier_total', headers=headers,
#                       params=params)
#print(chamado.status_code)
#resposta_JSON = json.loads(chamado.content)
#print(resposta_JSON)
# Out:
# 200
# b'"Hello Zimmer Gomes!"'
# 200
# b'{"access_token":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE2ODkxODU3MDAsInN1YiI6IjE3In0.6wqQQq9vBa44zseGECQptx5TSud6CZ9CMAHbfl5_PwM","token_type":"bearer"}'
# 200
# ['MET OFFICE', 'THE HISTORIC BUILDINGS AND MONUMENTS COMMISSION FOR ENGLAND', 'TORBAY COUNCIL']

# %% [markdown]
# DATAFRAME

# %%
df
# Out:
#                                                    0
# 0                                         MET OFFICE
# 1  THE HISTORIC BUILDINGS AND MONUMENTS COMMISSIO...
# 2                                     TORBAY COUNCIL

# %% [markdown]
# PESQUISA DE COLUNAS DO DATAFRAME

# %%
df['results']
# Out:
# 0    {'publicationPolicy': 'https://openopps.com/le...
# 1    {'publicationPolicy': 'https://openopps.com/le...
# Name: results, dtype: object

# %% [markdown]
# RESULTADO N1 DA COLUNA " " DO DATAFRAME

# %%
df['results'][0]
# Out:
#                              id                                    value  \
# 0    DCM048_THBAM_gov_2021_09_3   {'amount': 35000.0, 'currency': 'GBP'}
# 1    DCM048_THBAM_gov_2021_09_5   {'amount': 30416.4, 'currency': 'GBP'}
# 2    DCM048_THBAM_gov_2021_09_9  {'amount': 15571.26, 'currency': 'GBP'}
# 3   DCM048_THBAM_gov_2021_09_11  {'amount': 10547.54, 'currency': 'GBP'}
# 4   DCM048_THBAM_gov_2021_09_13  {'amount': 45192.72, 'currency': 'GBP'}
# ..                          ...                                      ...
# 95     E1102_TC_gov_2021_09_425      {'amount': 60.0, 'currency': 'GBP'}
# 96     E1102_TC_gov_2021_09_433   {'amount': 2092.01, 'currency': 'GBP'}
# 97     E1102_TC_gov_2021_09_437     {'amount': 704.0, 'currency': 'GBP'}
# 98     E1102_TC_gov_2021_09_444    {'amount': 1043.4, 'currency': 'GBP'}
# 99     E1102_TC_gov_2021_09_449    {'amount': 1591.0, 'currency': 'GBP'}
#
#                                                 buyer        date  \
# ...

# %% [markdown]
# TESTE DE ROTAS

# %%
df['results'][0]['releases'][0]['tender']['description']
# Out:
# 'Las presentes Bases Administrativas, tienen por objeto regular el proceso de Licitación Pública: Apertura, Evaluación, Adjudicación, Contratación y Recepción de los productos sujetos en la presente Licitación. Los productos se refieren a la venta, despacho y entrega de fármacos para el Hospital de Puerto Montt ejecutado mediante un Convenio de Suministros.'

# %% [markdown]
# NOTICES - RECORDS / BY ID

# %%
import os

name_list = []
endDate_list = []
startDate_list = []
descr_list = []
title_list = []
language_list = []
link_list = []
cpv_list = []

for i in range(101):  
    if i < len(df['results']):
        
        try:
            name = df['results'][i]['releases'][0]['parties'][0]['name']
        except KeyError:
            name = 'X'
        name_list.append(name)
        
        try:
            endDate = df['results'][i]['releases'][0]['tender']['tenderPeriod']['endDate']
        except KeyError:
            endDate = 'X'
        endDate_list.append(endDate)
        
        try:
            startDate = df['results'][i]['releases'][0]['tender']['tenderPeriod']['startDate']
        except KeyError:
            startDate = 'x'
        startDate_list.append(startDate)
        
        try:
            descr = df['results'][i]['releases'][0]['tender']['description']
        except KeyError:
            descr = 'X'
        descr_list.append(descr)
        
        try:
            title = df['results'][i]['releases'][0]['tender']['title']
        except KeyError:
            title = 'X'
        title_list.append(title)
        
        try:
            language = df['results'][i]['releases'][0]['language']
        except KeyError:
            language = 'X'
        language_list.append(language)
        
        try:
            link = df['results'][i]['releases'][0]['tender']['documents'][0]['url']
        except KeyError:
            link = 'X'
        link_list.append(link)
        
        try:
            cpv = df['results'][i]['releases'][1]['tender']['items'][0]['additionalClassifications'][0]['id']
        except KeyError:
            cpv = 'X'
        cpv_list.append(cpv)
        
    else:
        break 
    
data = {'name': name_list,
        'title' : title_list,
        'description' : descr_list,
        'cpv' : cpv_list,
        'StartDate':startDate_list,
        'EndDate' : endDate_list,
        'link':link_list,
        'language':language_list}

df_new = pd.DataFrame(data)
desktop_path = os.path.expanduser("~/Desktop")
excel_file_path = os.path.join(desktop_path, "NoticesRecords.xlsx")
df_new.to_excel(excel_file_path, index=False)

# %% [markdown]
# TRANSACTION - RECORDS

# %%
import os

id_list = []

#value
value_amount_list = []
value_currency_list = []

#buyer
buyer_name_list = []
buyer_id_list = []
buyer_identifier_list = []
buyer_additionalIdentifiers_list = []
buyer_andress_list = []
buyer_contactPoint_list = []
buyer_roles_list = []
buyer_categorization_level1_list = []
buyer_categorization_level2_list = []
buyer_categorization_level3_list = []

date_list = []
classification_list = []

#supplier
supplier_name_list = []
supplier_id_list = []
supplier_identifier_list = []
supplier_streetAddress_list = []
supplier_locality_list = []
supplier_region_list = []
supplier_postalCode_list = []
supplier_countryName_list = []
supplier_contactPoint_list = []
supplier_roles_list = []
supplier_countryEntityId_list = []
supplier_districtEntityId_list = []
supplier_district_entity_name_list = []
supplier_is_sme_list = []
supplier_geo_point_list = []
supplier_status_list = []
supplier_type_list = []

service_list = []
content_list = []
updateDate_list = []

for i in range(101):  
    if i < len(df['id']):
        try:
            id = df['id'][i]
        except KeyError:
            id = 'X'
        id_list.append(id)
    else:
        break
for i in range(101):  
    if i < len(df['value']):
        try: 
            value_amount = df['value'][i]['amount']
        except KeyError:
            value_amount = 'x'
        value_amount_list.append(value_amount)
        try:
            value_currency = df['value'][i]['currency']
        except KeyError:
            value_currency = 'x' 
        value_currency_list.append(value_currency)
    else:
        break
for i in range(101):  
    if i < len(df['buyer']):
        try: 
            buyer_name = df['buyer'][i]['name']
        except KeyError:
            buyer_name = 'x'
        buyer_name_list.append(buyer_name)
        try:
            buyer_id = df['buyer'][i]['id']
        except KeyError:
            buyer_id = 'x'
        buyer_id_list.append(buyer_id)
        try:
            buyer_identifier = df['buyer'][i]['identifier']
        except KeyError:
            buyer_identifier = 'x'
        buyer_identifier_list.append(buyer_identifier)
        try:
            buyer_additionalIdentifiers = df['buyer'][i]['additionalIdentifiers']
        except KeyError:
            buyer_additionalIdentifiers = 'x'
        buyer_additionalIdentifiers_list.append(buyer_additionalIdentifiers)
        try:
            buyer_andress = df['buyer'][i]['address']
        except KeyError:
            buyer_andress = 'x'
        buyer_andress_list.append(buyer_andress)
        try:
            buyer_contactPoint = df['buyer'][i]['contactPoint']
        except KeyError:
            buyer_contactPoint = 'x'
        buyer_contactPoint_list.append(buyer_contactPoint)
        try:
            buyer_roles = df['buyer'][i]['roles']
        except KeyError:
            buyer_roles = 'x'
        buyer_roles_list.append(buyer_roles)
        try:
            buyer_categorization_level1 = df['buyer'][i]['details']['categorization_level1']
        except KeyError:
            buyer_categorization_level1 = 'X'
        buyer_categorization_level1_list.append(buyer_categorization_level1)
        try:
            buyer_categorization_level2 = df['buyer'][i]['details']['categorization_level2']
        except KeyError:
            buyer_categorization_level2 = 'X'
        buyer_categorization_level2_list.append(buyer_categorization_level2)
        try:
            buyer_categorization_level3 = df['buyer'][i]['details']['categorization_level3']
        except KeyError:
            buyer_categorization_level3 = 'X'
        buyer_categorization_level3_list.append(buyer_categorization_level3)
    else:
        break
for i in range(101):  
    if i < len(df['date']):
        try: 
            date = df['date'][i]
        except KeyError:
            date = 'x'
        date_list.append(date)
    else:
        break
for i in range(101):  
    if i < len(df['classification']):   
        try: 
            classification = df['classification'][i]
        except KeyError:
            classification = 'x'
        classification_list.append(classification)
    else:
        break
for i in range(101):  
    if i < len(df['supplier']): 
        try:
            supplier_name = df['supplier'][i]['name']
        except KeyError:
            supplier_name = 'x'
        supplier_name_list.append(supplier_name)
        try:
            supplier_id = df['supplier'][i]['id']
        except KeyError:
            supplier_id = 'x'
        supplier_id_list.append(supplier_id)
        try:
            supplier_identifier = df['supplier'][i]['identifier']
        except KeyError:
            supplier_identifier = 'x'
        supplier_identifier_list.append(supplier_identifier)
        try:
            supplier_streetAddress = df['supplier'][i]['address']['streetAddress']
        except KeyError:
            supplier_streetAddress = 'x'
        supplier_streetAddress_list.append(supplier_streetAddress)
        try:
            supplier_locality = df['supplier'][i]['address']['locality']
        except KeyError:
            supplier_locality = 'x'
        supplier_locality_list.append(supplier_locality)
        try:
            region = df['supplier'][i]['address']['region']
        except KeyError:
            supplier_region_list = 'x'
        supplier_region_list.append(region)
        try:
            supplier_postalCode = df['supplier'][i]['address']['postalCode']
        except KeyError:
            supplier_postalCode = 'x'
        supplier_postalCode_list.append(supplier_postalCode)
        try:
            supplier_countryName = df['supplier'][i]['address']['countryName']
        except KeyError:
            supplier_countryName = 'x'
        supplier_countryName_list.append(supplier_countryName)
        try:
            supplier_contactPoint = df['supplier'][i]['contactPoint']
        except KeyError:
            supplier_contactPoint = 'x'
        supplier_contactPoint_list.append(supplier_contactPoint)
        try:
            supplier_roles = df['supplier'][i]['roles']
        except KeyError:
            supplier_roles = 'x' 
        supplier_roles_list.append(supplier_roles)
        try:
            supplier_countyEntityId = df['supplier'][i]['details']['countyEntityId']
        except KeyError:
            supplier_countyEntityId = 'X'
        supplier_countryEntityId_list.append(supplier_countyEntityId)
        try:
            supplier_districtEntityId = df['supplier'][i]['details']['districtEntityId']
        except KeyError:
            supplier_districtEntityId = 'x'
        supplier_districtEntityId_list.append(supplier_districtEntityId)
        try:
            supplier_district_entity_name = df['supplier'][i]['details']['district_entity_name']
        except KeyError:
            supplier_district_entity_name = 'x'
        supplier_district_entity_name_list.append(supplier_district_entity_name)
        try:
            supplier_is_sme = df['supplier'][i]['details']['is_sme']
        except KeyError:
            supplier_is_sme = 'x'
        supplier_is_sme_list.append(supplier_is_sme)
        try: 
            supplier_geo_point = df['supplier'][i]['details']['postcode_geo_point']
        except KeyError:
            supplier_geo_point = 'x'
        supplier_geo_point_list.append(supplier_geo_point)
        try:
            supplier_status = df['supplier'][i]['details']['status']
        except KeyError:
            supplier_status = 'x'
        supplier_status_list.append(supplier_status)
        try:
            supplier_type = df['supplier'][i]['details']['type']
        except KeyError:
            supplier_type = 'x'
        supplier_type_list.append(supplier_type)
    else:
        break
for i in range(101):  
    if i < len(df['service']):
        try: 
            service = df['service'][i]
        except KeyError:
            service = 'x'
        service_list.append(service)
    else:
        break
for i in range(101):  
    if i < len(df['content']):
        try: 
            content = df['content'][i]
        except KeyError:
            content = 'x'
        content_list.append(content)
    else:
        break
for i in range(101):  
    if i < len(df['updateDate']):
        try: 
            updateDate = df['updateDate'][i]
        except KeyError:
            updateDate = 'x'
        updateDate_list.append(updateDate) 
    else:
        break
    
data = {'id': id_list,
        'amount' : value_amount_list,
        'currency' : value_currency_list,
        'buyer_name' : buyer_name_list,
        'buyer_id' : buyer_id_list,
        'buyer_identifier' : buyer_identifier_list,
        'buyer_addtionalIdentifiers' : buyer_additionalIdentifiers_list,
        'buyer_andress':buyer_andress_list,
        'buyer_contactPoint': buyer_contactPoint_list,
        'buyer_roles' : buyer_roles_list,
        'buyer_categorization_level1' : buyer_categorization_level1_list,
        'buyer_categorization_level2' : buyer_categorization_level2_list,
        'buyer_categorization_level3' : buyer_categorization_level3_list,
        'date' : date_list,
        'classification': classification_list,
        'supplier_name' : supplier_name_list,
        'supplier_id' : supplier_id_list,
        'supplier_identifier' : supplier_identifier_list,
        'supplier_streetAddress' : supplier_streetAddress_list,
        'supplier_locality': supplier_locality_list,
        'supplier_region' : supplier_region_list,
        'supplier_postaCode' : supplier_postalCode_list,
        'supplier_countyName' : supplier_countryName_list,
        'supplier_contactPoint' : supplier_contactPoint_list,
        'supplier_roles' : supplier_roles_list,
        'supplier_countyEntityId' : supplier_countryEntityId_list,
        'supplier_districtEntityId' : supplier_districtEntityId_list,
        'supplier_district_entity_name' : supplier_district_entity_name_list,
        'supplier_is_sme': supplier_is_sme_list,
        'supplier_geo_point': supplier_geo_point_list,
        'supplier_status' : supplier_status_list,
        'supplier_type' : supplier_type_list,
        'service':service_list,
        'content':content_list,
        'updateDate' : updateDate_list }

df_new = pd.DataFrame(data)
desktop_path = os.path.expanduser("~/Desktop")
excel_file_path = os.path.join(desktop_path, "TransactionRecords.xlsx")
df_new.to_excel(excel_file_path, index=False)

# %% [markdown]
# AGREGATE_AMOUNT

# %%
import os 

agregate_amount_list = []
agregate_buyer_name_list = []
agregate_supplier_name = []
agregate_classification_proclass_level1_list = []
agregate_classification_proclass_level2_list = []


for i in range(101):  
    if i < len(df['amount']):
        try:
            agregate_amount = df['amount'][i]
        except KeyError:
            agregate_amount = 'X'
        agregate_amount_list.append(agregate_amount)
    else:
        break
for i in range(101):
    if i < len(df['buyer_name']):
        try:
            buyer_name = df['buyer_name'][i]
        except KeyError:
            buyer_name = 'X'
        agregate_buyer_name_list.append(buyer_name)
    else:
        break
for i in range(101):
    if i < len(df['supplier_name']):
        try:
            supplier_name = df['supplier_name'][i]
        except KeyError:
            supplier_name = 'X'
        agregate_supplier_name.append(supplier_name)
    else:
        break
for i in range(101):
    if i < len(df['classification_proclass_level1']):
        try:
            classification_proclass_level1 = df['classification_proclass_level1'][i]
        except KeyError:
            classification_proclass_level1 = 'X'
        agregate_classification_proclass_level1_list.append(classification_proclass_level1)
    else:
        break
for i in range(101):
    if i < len(df['classification_proclass_level2']):
        try:
            classification_proclass_level2 = df['classification_proclass_level2'][i]
        except KeyError:
            classification_proclass_level2 = 'X'
        agregate_classification_proclass_level2_list.append(classification_proclass_level2)
    else:
        break

data = { 'amount' : agregate_amount_list,
         'buyer_name' : agregate_buyer_name_list,
         'supplier_name': agregate_supplier_name,
         'classification_proclass_level1' : classification_proclass_level1,
         'classification_proclass_level2' : classification_proclass_level2
}
df_new = pd.DataFrame(data)
desktop_path = os.path.expanduser("~/Desktop")
excel_file_path = os.path.join(desktop_path, "TransactionAgregateAmount.xlsx")
df_new.to_excel(excel_file_path, index=False)

# %% [markdown]
# TIMELINE

# %%
import os

year_list = []
amount_list = []

for i in range(101):
    if i < len(df['year']):
        try:
            year = df['year'][i]
        except KeyError:
            supplier_name = 'X'
        year_list.append(year)
    else:
        break
    
for i in range(101):
    if i < len(df['amount']):
        try:
            amount = df['amount'][i]
        except KeyError:
            amount = 'X'
        amount_list.append(amount)
    else:
        break
    
data =  { 'year':year_list,
          'amount':amount_list
          }
df_new = pd.DataFrame(data)
desktop_path = os.path.expanduser("~/Desktop")
excel_file_path = os.path.join(desktop_path, "TransactionTimeLine.xlsx")
df_new.to_excel(excel_file_path, index=False)

# %% [markdown]
# SPEND VALUES

# %%
name_list = []

for i in range(101):
    if i < len(df):
        try:
            name = df[i]
        except KeyError:
            name = 'X'
        name_list.append(name)
    else:
        break
data = {
    'spend value':name_list
}

df_new = pd.DataFrame(data)
desktop_path = os.path.expanduser("~/Desktop")
excel_file_path = os.path.join(desktop_path, "TransactionSpendValues.xlsx")
df_new.to_excel(excel_file_path, index=False)
